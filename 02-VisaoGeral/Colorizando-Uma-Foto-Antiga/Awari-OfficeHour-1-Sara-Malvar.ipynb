# %% [markdown]
# #AWARI - PRIMEIRO OFFICE HOUR

# %% [markdown]
# #### Conhecendo o Google COLAB

# %% [markdown]
# **Ciência de Dados**
#
# Lista
# - +Código = Definições de instruções
# - +Texto = Comentários
# - [Link Google](https://www.google.com)

# %% [markdown]
# Alguns exemplos de +Código

# %% [markdown]
# Código aritmético

# %%
1+5
# Out:
# 6

# %% [markdown]
# Código de impressão

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# Código de definição e atribuição de variável

# %%
a=5

# %% [markdown]
# Utilização da variável

# %%
5*a
# Out:
# 25

# %% [markdown]
# #### Instruções Linux

# %% [markdown]
# Download
#
# **!wget** + URL
#
# **!wget** https://github.com/awarischool/data-science/blob/master/image-colorizer/deoldify_wrapper.py

# %% [markdown]
# **Observação**: A instrução acima vai apresentar problema de download, pois a URL é da página "visual" do GitHub e não do código.

# %% [markdown]
# Para efetuar download de códigos do GitHub utilizar o link do botão **Raw** da página do GitHub

# %% [markdown]
# ![raw.png](data:image/png;base64,...)

# %% [markdown]
# Download da biblioteca DeOldify para colorir imagens em preto e branco.
#
# !wget https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py

# %% [markdown]
# #### Colorizando Imagem

# %% [markdown]
# ##### Download do Programa

# %% [markdown]
# A instrução **#hide** oculta as linhas de códigos utilizadas quando são executadas.

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-12-18 19:57:01--  https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-18 19:57:01 (48.4 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %% [markdown]
# Após execução do download a visualização do Colab deve ser similar a imagem abaixo.

# %% [markdown]
# ![dw_deoldify_wrapper_py.png](data:image/png;base64,...)

# %% [markdown]
# ##### Importar a classe DeOldify

# %% [markdown]
# Trecho do código
#
# Definição da classe DeOldify
#
# ![class_deoldify.png](data:image/png;base64,...)

# %%
#hide
from deoldify_wrapper import DeOldify
# Out:
#   Importing Libraries
# No module named 'deoldify'
# DeOldify not found, installing..
#   Cloning DeOldify Repository...
#   Opening DeOldify Folder
#   Importing Libraries
# /content/deoldify_wrapper.py:36: UserWarning: WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings
#   warnings.warn('WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings')
#   Installing Colab requirements...
#   Importing DeOldify Visualize module and FastAI
# ...

# %% [markdown]
# Após execução do comando a visão do Colab deve ser similar a imagem abaixo.

# %% [markdown]
# ![import_class_deoldify.png](data:image/png;base64,...)

# %% [markdown]
# ##### Instanciar a classe
#
# Definição de variável com a classe DeOldify

# %%
#hide
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...
# Done!

# %% [markdown]
# Aguarde a execução do comando até completar 100% (Done!). A visão do Colab deve ser similar a imagem abaixo.

# %% [markdown]
# ![instaciar_class_deoldify.png](data:image/png;base64,...)

# %% [markdown]
# ##### Colorindo as imagens
#
# Utilização do método **.colorize**

# %%
#hide_input
deo.colorize('https://static.boredpanda.com/blog/wp-content/uploads/2014/08/cat-looking-at-you-black-and-white-photography-1.jpg')

# %%
#hide_input
deo.colorize('https://static.boredpanda.com/blog/wp-content/uploads/2014/08/cat-black-and-white-photography-6.jpg')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
